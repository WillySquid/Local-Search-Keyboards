# %%
import numpy as np
import scipy.cluster.hierarchy as sch

# %%
#S is matrix of distances between top 100 keyboard layouts

# %%
#Z is a linkage matrix done with complete linkage method
Z = sch.complete(S)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-80c28366caae> in <module>
#       1 #Z is a linkage matrix done with complete linkage method
# ----> 2 Z = sch.complete(S)
#
# NameError: name 'S' is not defined

# %%
#D is the dendrogram of Z
D = sch.dendrogram(Z)

# %%
#finds the clusters
#note that the constant of 0.7 was determined experimentally

ind = sch.fcluster(Z, 0.7*Z.max(), 'distance')
ind = ind.tolist()

pairs = list(zip(ind, range(len(S))))
clusters = sorted(pairs)

# %%
#finds the permutation applied to the list of keyboard layouts to achieve the final order based on clusters
ignore, perm = zip(*lev)

# %%
#S is matrix of distances between top 100 keyboard layouts, the same as S

# %%
#creates new matrix of scores now ordered by cluster
new_m = []

for i in perm:
    r=m[i]
    new_r = []
    for i in perm:
        new_r.append(r[i])
    new_m.append(new_r)

# %%
#plots heatmap
import matplotlib.pyplot as plt
import numpy as np

a = new_m
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()
